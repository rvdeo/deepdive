# %%
import tensorflow as tf
import pathlib
import PIL
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import shutil
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from utils import *
from mc_coral_classifier import *

# %%
folder_path = "Dataset_generated"
images, labels = read_images_in_folder(folder_path)
print(f"Total number of images: {len(images)}")
print(f"Total number of labels: {len(labels)}")
distinct_labels = list(set(labels))

print(distinct_labels)
# Out:
# 2023-10-03 13:15:17.764298: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Total number of images: 3994
# Total number of labels: 3994
# ['Octopods', 'Stalked Erect sponges', 'Sea stars', 'Squat lobsters', 'Laminar Erect sponges', 'General unknown biology', 'Irregular urchins', 'Snake stars', 'Other anemones', 'Sea Cucumber', 'Sea urchins', 'Bony fishes', 'Arborescent coral', 'Prawns - Shrimps - Mysids', 'Anthomastus Like coral', 'True lobsters', 'Feather stars', 'Sea whip coral', 'Hermit Crab with Shell or Stone', 'Tube anemones', 'Arborescent Stumpy Grey Branching Erect sponges', 'Bioturbation - Organism tests', 'Ctenophores jellies', 'Colonial Unstalked Ascidian', 'Simple Branching coral', 'Crab', 'Free-living coral', 'Woody debris', 'Cup-likes sponges', 'Tube worms', 'Quill (Sea pen) coral', 'Eels', 'Attached Stony coral']

# %%
 imagenet_data = pd.read_html('https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/')[0]

# %%
imagenet_data[]
# Out:
#      Class ID                                         Class Name
# 0           0                                 tench, Tinca tinca
# 1           1                        goldfish, Carassius auratus
# 2           2  great white shark, white shark, man-eater, man...
# 3           3                    tiger shark, Galeocerdo cuvieri
# 4           4                       hammerhead, hammerhead shark
# ..        ...                                                ...
# 995       995                                          earthstar
# 996       996  hen-of-the-woods, hen of the woods, Polyporus ...
# 997       997                                             bolete
# 998       998                              ear, spike, capitulum
# 999       999       toilet tissue, toilet paper, bathroom tissue
#
# [1000 rows x 2 columns]

# %%
for label in distinct_labels:
    print (label, " --> ", imagenet_data['Class Name'].str.contains(label[:3]).sum())
# Out:
# Octopods  -->  0
# Stalked Erect sponges  -->  2
# Sea stars  -->  1
# Squat lobsters  -->  0
# Laminar Erect sponges  -->  0
# General unknown biology  -->  0
# Irregular urchins  -->  0
# Snake stars  -->  0
# Other anemones  -->  0
# Sea Cucumber  -->  1
# Sea urchins  -->  1
# Bony fishes  -->  1
# Arborescent coral  -->  0
# Prawns - Shrimps - Mysids  -->  0
# Anthomastus Like coral  -->  0
# True lobsters  -->  0
# Feather stars  -->  0
# Sea whip coral  -->  1
# Hermit Crab with Shell or Stone  -->  0
# Tube anemones  -->  0
# Arborescent Stumpy Grey Branching Erect sponges  -->  0
# Bioturbation - Organism tests  -->  0
# Ctenophores jellies  -->  0
# Colonial Unstalked Ascidian  -->  0
# Simple Branching coral  -->  0
# Crab  -->  0
# Free-living coral  -->  3
# Woody debris  -->  0
# Cup-likes sponges  -->  0
# Tube worms  -->  0
# Quill (Sea pen) coral  -->  0
# Eels  -->  0
# Attached Stony coral  -->  0

# %%
imagenet_data[['Class Name']].values
# Out:
# array([['tench, Tinca tinca'],
#        ['goldfish, Carassius auratus'],
#        ["great white shark, white shark, man-eater, man-eating shark, Carcharodon caharias',"],
#        ['tiger shark, Galeocerdo cuvieri'],
#        ['hammerhead, hammerhead shark'],
#        ['electric ray, crampfish, numbfish, torpedo'],
#        ['stingray'],
#        ['cock'],
#        ['hen'],
#        ['ostrich, Struthio camelus'],
#        ['brambling, Fringilla montifringilla'],
#        ['goldfinch, Carduelis carduelis'],
#        ['house finch, linnet, Carpodacus mexicanus'],
#        ['junco, snowbird'],
#        ['indigo bunting, indigo finch, indigo bird, Passerina cyanea'],
#        ['robin, American robin, Turdus migratorius'],
#        ['bulbul'],
#        ['jay'],
#        ['magpie'],
#        ['chickadee'],
#        ['water ouzel, dipper'],
#        ['kite'],
#        ['bald eagle, American eagle, Haliaeetus leucocephalus'],
#        ['vulture'],
# ...

# %%
distinct_labels
# Out:
# ['Octopods',
#  'Stalked Erect sponges',
#  'Sea stars',
#  'Squat lobsters',
#  'Laminar Erect sponges',
#  'General unknown biology',
#  'Irregular urchins',
#  'Snake stars',
#  'Other anemones',
#  'Sea Cucumber',
#  'Sea urchins',
#  'Bony fishes',
#  'Arborescent coral',
#  'Prawns - Shrimps - Mysids',
#  'Anthomastus Like coral',
#  'True lobsters',
#  'Feather stars',
#  'Sea whip coral',
#  'Hermit Crab with Shell or Stone',
#  'Tube anemones',
#  'Arborescent Stumpy Grey Branching Erect sponges',
#  'Bioturbation - Organism tests',
#  'Ctenophores jellies',
#  'Colonial Unstalked Ascidian',
#  'Simple Branching coral',
#  'Crab',
#  'Free-living coral',
#  'Woody debris',
#  'Cup-likes sponges',
#  'Tube worms',
#  'Quill (Sea pen) coral',
#  'Eels',
#  'Attached Stony coral']

# %%
for label in distinct_labels:
    print (label)
# Out:
# Octopods
# Stalked Erect sponges
# Sea stars
# Squat lobsters
# Laminar Erect sponges
# General unknown biology
# Irregular urchins
# Snake stars
# Other anemones
# Sea Cucumber
# Sea urchins
# Bony fishes
# Arborescent coral
# Prawns - Shrimps - Mysids
# Anthomastus Like coral
# True lobsters
# Feather stars
# Sea whip coral
# Hermit Crab with Shell or Stone
# Tube anemones
# Arborescent Stumpy Grey Branching Erect sponges
# Bioturbation - Organism tests
# Ctenophores jellies
# Colonial Unstalked Ascidian
# Simple Branching coral
# Crab
# Free-living coral
# Woody debris
# Cup-likes sponges
# Tube worms
# Quill (Sea pen) coral
# Eels
# Attached Stony coral
